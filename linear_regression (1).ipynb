# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/headbrain.csv")
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               237 non-null    int64
#  1   Age Range            237 non-null    int64
#  2   Head Size(cm^3)      237 non-null    int64
#  3   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
df.describe()
# Out:
#            Gender   Age Range  Head Size(cm^3)  Brain Weight(grams)
# count  237.000000  237.000000       237.000000           237.000000
# mean     1.434599    1.535865      3633.991561          1282.873418
# std      0.496753    0.499768       365.261422           120.340446
# min      1.000000    1.000000      2720.000000           955.000000
# 25%      1.000000    1.000000      3389.000000          1207.000000
# 50%      1.000000    2.000000      3614.000000          1280.000000
# 75%      2.000000    2.000000      3876.000000          1350.000000
# max      2.000000    2.000000      4747.000000          1635.000000

# %%
x = df[["Head Size(cm^3)"]]
y = df[["Brain Weight(grams)"]]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size= 0.8)

# %%
from sklearn.linear_model import LinearRegression

ss = LinearRegression()
reg = ss.fit(x_train,y_train)

y_pred = reg.predict(x_test)

# %%
x_test
# Out:
#      Head Size(cm^3)
# 165             3082
# 112             3571
# 118             4114
# 145             3899
# 141             3530
# 54              4012
# 231             3704
# 32              4103
# 104             3618
# 86              3309
# 140             3572
# 94              3700
# 169             3566
# 202             3277
# 98              3654
# 106             4032
# 108             3916
# 75              3394
# 6               3785
# 21              4046
# 120             3399
# 69              4381
# 201             3228
# 159             3269
# 133             3667
# 53              4063
# 188             3394
# 36              3527
# 72              4121
# 171             3503
# 18              3095
# 59              3669
# 64              3727
# 227             4204
# 65              3329
# 101             3834
# 70              4008
# 174             3615
# 143             3438
# 224             3647
# 84              3933
# 48              3641
# ...

# %%
y_pred
# Out:
# array([[1133.22156571],
#        [1264.10375386],
#        [1409.43918978],
#        [1351.89385143],
#        [1253.12999166],
#        [1382.13861065],
#        [1299.70156781],
#        [1406.49500968],
#        [1276.68343248],
#        [1193.9787369 ],
#        [1264.3714066 ],
#        [1298.63095687],
#        [1262.76549018],
#        [1185.41384933],
#        [1286.31893099],
#        [1387.49166538],
#        [1356.44394795],
#        [1216.7292195 ],
#        [1321.38143947],
#        [1391.2388037 ],
#        [1218.06748318],
#        [1480.90247042],
#        [1172.29886524],
#        [1183.27262744],
#        [1289.79841656],
#        [1395.78890022],
#        [1216.7292195 ],
#        [1252.32703345],
#        [1411.31275893],
#        [1245.90336778],
#        [1136.70105129],
#        [1290.33372204],
#        [1305.85758075],
#        [1433.52793606],
#        [1199.33179163],
#        [1334.49642356],
#        [1381.06799971],
#        [1275.88047427],
# ...

# %%
y_test
# Out:
#      Brain Weight(grams)
# 165                 1180
# 112                 1295
# 118                 1362
# 145                 1380
# 141                 1252
# 54                  1400
# 231                 1220
# 32                  1364
# 104                 1290
# 86                  1120
# 140                 1270
# 94                  1290
# 169                 1306
# 202                 1105
# 98                  1242
# 106                 1425
# 108                 1360
# 75                  1195
# 6                   1400
# 21                  1287
# 120                 1173
# 69                  1415
# 201                 1235
# 159                 1241
# 133                 1310
# 53                  1390
# 188                 1243
# 36                  1375
# 72                  1380
# 171                 1240
# 18                  1340
# 59                  1222
# 64                  1470
# 227                 1380
# 65                  1135
# 101                 1430
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter (x_test,y_pred,color = "cyan")
plt.scatter (x_test,y_test,color = "blue")

# %%
from sklearn.metrics import r2_score

print(r2_score (y_test,y_pred))
# Out:
# 0.5518361388578195

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 4788.399771813299
# 69.1982642254363

# %%
reg.predict([[2624]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1010.6366124]])

# %%
reg.predict([[654654]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[175528.25038885]])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("/content/cars.csv")
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Car     36 non-null     object
#  1   Model   36 non-null     object
#  2   Volume  36 non-null     int64
#  3   Weight  36 non-null     int64
#  4   CO2     36 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#             Volume       Weight         CO2
# count    36.000000    36.000000   36.000000
# mean   1611.111111  1292.277778  102.027778
# std     388.975047   242.123889    7.454571
# min     900.000000   790.000000   90.000000
# 25%    1475.000000  1117.250000   97.750000
# 50%    1600.000000  1329.000000   99.000000
# 75%    2000.000000  1418.250000  105.000000
# max    2500.000000  1746.000000  120.000000

# %%
x = df[["Volume","Weight"]]
y = df[["CO2"]]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2)

# %%
from sklearn.linear_model import LinearRegression
df = LinearRegression()
ss = df.fit(x_train,y_train)
y_pred = ss.predict(x_test)

# %%
y_pred
# Out:
# array([[107.58548462],
#        [102.32892414],
#        [102.72107481],
#        [ 99.97355122],
#        [106.69167205],
#        [100.15655487],
#        [100.94986092],
#        [102.28070437]])

# %%
y_test
# Out:
#     CO2
# 17  104
# 15   97
# 33  108
# 8    98
# 21   99
# 4   105
# 18  104
# 25  102

# %%
x_train
# Out:
#     Volume  Weight
# 31    2000    1746
# 34    1600    1405
# 13    1600    1252
# 22    2100    1365
# 1     1200    1160
# 28    1600    1523
# 23    1600    1415
# 0     1000     790
# 16    1600    1365
# 12    1000    1112
# 11    1300     990
# 5     1000     929
# 24    2000    1415
# 9     1600    1150
# 10    1100     980
# 7     1500    1365
# 32    1600    1235
# 26    2000    1490
# 35    2500    1395
# 14    1600    1326
# 20    1600    1584
# 27    2000    1725
# 2     1000     929
# 6     1400    1109
# 3      900     865
# 29    2000    1705
# 30    2100    1605
# 19    2000    1328

# %%
x_test
# Out:
#     Volume  Weight
# 17    2200    1280
# 15    1600    1330
# 33    1600    1390
# 8     1500    1112
# 21    2000    1428
# 4     1500    1140
# 18    1600    1119
# 25    1500    1465

# %%
x_volume = x_test["Volume"]
x_weight = x_test["Weight"]

plt.scatter(x_volume, y_pred, color="yellow", label="Volume")
plt.scatter(x_weight, y_pred, color="blue", label="Weight")
plt.xlabel("Volume and Weight")
plt.ylabel("Predicted CO2")
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score

print(r2_score(y_test,y_pred))
# Out:
# -0.6040632906739434

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
print(mse)
print(np.sqrt(mse))
# Out:
# 20.62725137851024
# 4.541723392998548

# %%
ss.predict([[1000,790]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[93.21621532]])
